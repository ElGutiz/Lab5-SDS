# %% [markdown]
# # Laboratorio No.5 de Security Data-Science
# ## Por Jose Gutierrez, 19111

# %% [markdown]
# <h1 style="color:rgb(102, 166, 38);">1° Part: Package Analyzer</h1>

# %% [markdown]
# <h3 style="color:rgb(102, 166, 38);">Importar librerias</h3>

# %%
from scapy.all import *
from scapy.layers.l2 import Ether
from scapy.layers.inet import IP
from scapy.layers.inet import TCP, UDP

import pandas as pd 
import numpy as np 
import binascii
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %% [markdown]
# <h3 style="color:rgb(102, 166, 38);">Capture 10 paquetes con la herramienta scapy, imprima el tipo de datos, la longitud y el
# contenido del pcap</h3>

# %%
scapy_cap_own = rdpcap('own.pcap')
n = 1
for packet in scapy_cap_own:
    print('Paquete No.', n, '\n')
    print(packet.show())
    print('\n')
    n += 1
# Out:
# Paquete No. 1
#
# ###[ Ethernet ]###
#   dst       = 14:4f:8a:34:91:76
#   src       = d4:ab:82:cb:ff:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 302
#      id        = 0
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = udp
#      chksum    = 0xb764
#      src       = 192.168.0.252
#      dst       = 192.168.0.14
#      \options   \
# ###[ UDP ]###
#         sport     = 39620
#         dport     = 64188
#         len       = 282
#         chksum    = 0x55e9
# ###[ Raw ]###
#            load      = 'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=1801\r\nDATE: Sun, 16 Apr 2023 21:50:21 GMT\r\nEXT:\r\nLOCATION: http://192.168.100.3:49152/wps_device.xml\r\nSERVER: Unspecified, UPnP/1.0, Unspecified\r\nST: upnp:rootdevice\r\nUSN: uuid:ba737a94-698b-506f-8de1-496651bea27b::upnp:rootdevice\r\n\r\n'
#
# None
#
#
# Paquete No. 2
#
# ###[ Ethernet ]###
#   dst       = 14:4f:8a:34:91:76
#   src       = d4:ab:82:cb:ff:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 302
#      id        = 0
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = udp
#      chksum    = 0xb764
#      src       = 192.168.0.252
#      dst       = 192.168.0.14
#      \options   \
# ###[ UDP ]###
#         sport     = 39620
#         dport     = 64188
#         len       = 282
#         chksum    = 0x55e9
# ###[ Raw ]###
#            load      = 'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=1801\r\nDATE: Sun, 16 Apr 2023 21:50:21 GMT\r\nEXT:\r\nLOCATION: http://192.168.100.3:49152/wps_device.xml\r\nSERVER: Unspecified, UPnP/1.0, Unspecified\r\nST: upnp:rootdevice\r\nUSN: uuid:ba737a94-698b-506f-8de1-496651bea27b::upnp:rootdevice\r\n\r\n'
#
# None
#
#
# Paquete No. 3
#
# ###[ Ethernet ]###
#   dst       = 14:4f:8a:34:91:76
#   src       = d4:ab:82:cb:ff:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 311
#      id        = 0
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = udp
#      chksum    = 0xb75b
#      src       = 192.168.0.252
#      dst       = 192.168.0.14
#      \options   \
# ###[ UDP ]###
#         sport     = 39620
#         dport     = 64188
#         len       = 291
#         chksum    = 0xf2cc
# ###[ Raw ]###
#            load      = 'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=1801\r\nDATE: Sun, 16 Apr 2023 21:50:21 GMT\r\nEXT:\r\nLOCATION: http://192.168.100.3:49152/wps_device.xml\r\nSERVER: Unspecified, UPnP/1.0, Unspecified\r\nST: uuid:ba737a94-698b-506f-8de1-496651bea27b\r\nUSN: uuid:ba737a94-698b-506f-8de1-496651bea27b\r\n\r\n'
#
# None
#
#
# Paquete No. 4
#
# ###[ Ethernet ]###
#   dst       = 14:4f:8a:34:91:76
#   src       = d4:ab:82:cb:ff:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 311
#      id        = 0
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = udp
#      chksum    = 0xb75b
#      src       = 192.168.0.252
#      dst       = 192.168.0.14
#      \options   \
# ###[ UDP ]###
#         sport     = 39620
#         dport     = 64188
#         len       = 291
#         chksum    = 0xf2cc
# ###[ Raw ]###
#            load      = 'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=1801\r\nDATE: Sun, 16 Apr 2023 21:50:21 GMT\r\nEXT:\r\nLOCATION: http://192.168.100.3:49152/wps_device.xml\r\nSERVER: Unspecified, UPnP/1.0, Unspecified\r\nST: uuid:ba737a94-698b-506f-8de1-496651bea27b\r\nUSN: uuid:ba737a94-698b-506f-8de1-496651bea27b\r\n\r\n'
#
# None
#
#
# Paquete No. 5
#
# ###[ Ethernet ]###
#   dst       = 14:4f:8a:34:91:76
#   src       = d4:ab:82:cb:ff:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 366
#      id        = 0
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = udp
#      chksum    = 0xb724
#      src       = 192.168.0.252
#      dst       = 192.168.0.14
#      \options   \
# ###[ UDP ]###
#         sport     = 39620
#         dport     = 64188
#         len       = 346
#         chksum    = 0x115
# ###[ Raw ]###
#            load      = 'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=1801\r\nDATE: Sun, 16 Apr 2023 21:50:21 GMT\r\nEXT:\r\nLOCATION: http://192.168.100.3:49152/wps_device.xml\r\nSERVER: Unspecified, UPnP/1.0, Unspecified\r\nST: urn:schemas-wifialliance-org:device:WFADevice:1\r\nUSN: uuid:ba737a94-698b-506f-8de1-496651bea27b::urn:schemas-wifialliance-org:device:WFADevice:1\r\n\r\n'
#
# None
#
#
# Paquete No. 6
#
# ###[ Ethernet ]###
#   dst       = 14:4f:8a:34:91:76
#   src       = d4:ab:82:cb:ff:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 366
#      id        = 0
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = udp
#      chksum    = 0xb724
#      src       = 192.168.0.252
#      dst       = 192.168.0.14
#      \options   \
# ###[ UDP ]###
#         sport     = 39620
#         dport     = 64188
#         len       = 346
#         chksum    = 0x115
# ###[ Raw ]###
#            load      = 'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=1801\r\nDATE: Sun, 16 Apr 2023 21:50:21 GMT\r\nEXT:\r\nLOCATION: http://192.168.100.3:49152/wps_device.xml\r\nSERVER: Unspecified, UPnP/1.0, Unspecified\r\nST: urn:schemas-wifialliance-org:device:WFADevice:1\r\nUSN: uuid:ba737a94-698b-506f-8de1-496651bea27b::urn:schemas-wifialliance-org:device:WFADevice:1\r\n\r\n'
#
# None
#
#
# Paquete No. 7
#
# ###[ Ethernet ]###
#   dst       = 14:4f:8a:34:91:76
#   src       = d4:ab:82:cb:ff:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 376
#      id        = 0
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = udp
#      chksum    = 0xb71a
#      src       = 192.168.0.252
#      dst       = 192.168.0.14
#      \options   \
# ###[ UDP ]###
#         sport     = 39620
#         dport     = 64188
#         len       = 356
#         chksum    = 0x8705
# ###[ Raw ]###
#            load      = 'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=1801\r\nDATE: Sun, 16 Apr 2023 21:50:21 GMT\r\nEXT:\r\nLOCATION: http://192.168.100.3:49152/wps_device.xml\r\nSERVER: Unspecified, UPnP/1.0, Unspecified\r\nST: urn:schemas-wifialliance-org:service:WFAWLANConfig:1\r\nUSN: uuid:ba737a94-698b-506f-8de1-496651bea27b::urn:schemas-wifialliance-org:service:WFAWLANConfig:1\r\n\r\n'
#
# None
#
#
# Paquete No. 8
#
# ###[ Ethernet ]###
#   dst       = 14:4f:8a:34:91:76
#   src       = d4:ab:82:cb:ff:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 376
#      id        = 0
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = udp
#      chksum    = 0xb71a
#      src       = 192.168.0.252
#      dst       = 192.168.0.14
#      \options   \
# ###[ UDP ]###
#         sport     = 39620
#         dport     = 64188
#         len       = 356
#         chksum    = 0x8705
# ###[ Raw ]###
#            load      = 'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=1801\r\nDATE: Sun, 16 Apr 2023 21:50:21 GMT\r\nEXT:\r\nLOCATION: http://192.168.100.3:49152/wps_device.xml\r\nSERVER: Unspecified, UPnP/1.0, Unspecified\r\nST: urn:schemas-wifialliance-org:service:WFAWLANConfig:1\r\nUSN: uuid:ba737a94-698b-506f-8de1-496651bea27b::urn:schemas-wifialliance-org:service:WFAWLANConfig:1\r\n\r\n'
#
# None
#
#
# Paquete No. 9
#
# ###[ Ethernet ]###
#   dst       = 01:00:5e:7f:ff:fa
#   src       = 14:4f:8a:34:91:76
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 129
#      id        = 42178
#      flags     =
#      frag      = 0
#      ttl       = 4
#      proto     = udp
#      chksum    = 0x60f9
#      src       = 192.168.0.14
#      dst       = 239.255.255.250
#      \options   \
# ###[ UDP ]###
#         sport     = 64188
#         dport     = ssdp
#         len       = 109
#         chksum    = 0xc51f
# ###[ Raw ]###
#            load      = 'M-SEARCH * HTTP/1.1\r\nHost: 239.255.255.250:1900\r\nST: upnp:rootdevice\r\nMan: "ssdp:discover"\r\nMX: 3\r\n\r\n'
#
# None
#
#
# Paquete No. 10
#
# ###[ Ethernet ]###
#   dst       = 14:4f:8a:34:91:76
#   src       = d4:ab:82:cb:ff:26
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 367
#      id        = 0
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = udp
#      chksum    = 0xb81e
#      src       = 192.168.0.1
#      dst       = 192.168.0.14
#      \options   \
# ###[ UDP ]###
#         sport     = ssdp
#         dport     = 64188
#         len       = 347
#         chksum    = 0xf9fa
# ###[ Raw ]###
#            load      = 'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=3600\r\nST: upnp:rootdevice\r\nUSN: uuid:fc384c04-c9e7-4094-8865-cbd7adaa3eb5::upnp:rootdevice\r\nEXT:\r\nSERVER: Linux/2.6.18_pro500 UPnP/1.0 MiniUPnPd/1.5\r\nLOCATION: http://192.168.0.1:5000/rootDesc.xml\r\nOPT: "http://schemas.upnp.org/upnp/1/0/";\r\n01-NLS: 1\r\nBOOTID.UPNP.ORG: 1\r\nCONFIGID.UPNP.ORG: 1337\r\n\r\n'
# None

# %% [markdown]
# <h3 style="color:rgb(102, 166, 38);">Añada al pcap de 10 paquetes el archivo analisis_paquetes.pcap</h3>

# %%
scapy_cap_alt = rdpcap('analisis_paquetes.pcap')

for packet in scapy_cap_alt:
    scapy_cap_own.append(packet)

# %% [markdown]
# <h3 style="color:rgb(102, 166, 38);">Convierta el pcap a un DataFrame</h3>

# %%
ip_fields = [field.name for field in IP().fields_desc]
tcp_fields = [field.name for field in TCP().fields_desc]
udp_fields = [field.name for field in UDP().fields_desc]

dataframe_fields = ip_fields + ['time'] + tcp_fields + ['payload','payload_raw','payload_hex']


df = pd.DataFrame(columns=dataframe_fields)
for packet in scapy_cap_own[IP]:
    
    field_values = []
    
    for field in ip_fields:
        if field == 'options':
           
            field_values.append(len(packet[IP].fields[field]))
        else:
            field_values.append(packet[IP].fields[field])
    
    field_values.append(packet.time)
    
    layer_type = type(packet[IP].payload)
    for field in tcp_fields:
        try:
            if field == 'options':
                field_values.append(len(packet[layer_type].fields[field]))
            else:
                field_values.append(packet[layer_type].fields[field])
        except:
            field_values.append(None)
    
    
    field_values.append(len(packet[layer_type].payload))
    field_values.append(packet[layer_type].payload.original)
    field_values.append(binascii.hexlify(packet[layer_type].payload.original))
    
    df_append = pd.DataFrame([field_values], columns=dataframe_fields)
    df = pd.concat([df, df_append], axis=0)


df = df.reset_index()

df = df.drop(columns="index")

# %%
df
# Out:
#    version ihl tos  len     id flags frag  ttl proto chksum  ... dataofs  \
# 0        4   5   0  302      0    DF    0   64    17  46948  ...    None
# 1        4   5   0  302      0    DF    0   64    17  46948  ...    None
# 2        4   5   0  311      0    DF    0   64    17  46939  ...    None
# 3        4   5   0  311      0    DF    0   64    17  46939  ...    None
# 4        4   5   0  366      0    DF    0   64    17  46884  ...    None
# ..     ...  ..  ..  ...    ...   ...  ...  ...   ...    ...  ...     ...
# 75       4   5  32   84   8744          0  122    17  64011  ...    None
# 76       4   5   0  969      1          0   64    17  21214  ...    None
# 77       4   5  32   84   9344          0  122    17  63411  ...    None
# 78       4   5   0  588      1          0   64    17  21595  ...    None
# 79       4   5  32   84  10094          0  122    17  62661  ...    None
#
#    reserved flags window chksum urgptr options payload  \
# 0      None  None   None  21993   None    None     274
# 1      None  None   None  21993   None    None     274
# 2      None  None   None  62156   None    None     283
# 3      None  None   None  62156   None    None     283
# 4      None  None   None    277   None    None     338
# ..      ...   ...    ...    ...    ...     ...     ...
# 75     None  None   None  65088   None    None      56
# 76     None  None   None    671   None    None     941
# 77     None  None   None  65089   None    None      56
# 78     None  None   None  54406   None    None     560
# 79     None  None   None  65090   None    None      56
#
#                                           payload_raw  \
# 0   b'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=18...
# 1   b'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=18...
# 2   b'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=18...
# 3   b'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=18...
# 4   b'HTTP/1.1 200 OK\r\nCACHE-CONTROL: max-age=18...
# ..                                                ...
# 75  b'\x00\x0c\x81\x80\x00\x01\x00\x01\x00\x00\x00...
# 76  b'\x00\x0c\x01\x00\x00\x01\x00\x00\x00\x00\x00...
# 77  b'\x00\x0c\x81\x80\x00\x01\x00\x01\x00\x00\x00...
# 78  b'\x00\x0c\x01\x00\x00\x01\x00\x00\x00\x00\x00...
# 79  b'\x00\x0c\x81\x80\x00\x01\x00\x01\x00\x00\x00...
#
#                                           payload_hex
# 0   b'485454502f312e3120323030204f4b0d0a4341434845...
# 1   b'485454502f312e3120323030204f4b0d0a4341434845...
# 2   b'485454502f312e3120323030204f4b0d0a4341434845...
# 3   b'485454502f312e3120323030204f4b0d0a4341434845...
# 4   b'485454502f312e3120323030204f4b0d0a4341434845...
# ..                                                ...
# 75  b'000c8180000100010000000006676f6f676c6503636f...
# 76  b'000c0100000100000000000006676f6f676c6503636f...
# 77  b'000c8180000100010000000006676f6f676c6503636f...
# 78  b'000c0100000100000000000006676f6f676c6503636f...
# 79  b'000c8180000100010000000006676f6f676c6503636f...
#
# [80 rows x 28 columns]

# %% [markdown]
# <h3 style="color:rgb(102, 166, 38);">Muestre los valores de las columnas: Src Addres, Dst Address, Src Port y Dst Port</h3>

# %%
df[['src','dst','sport','dport']]
# Out:
#               src           dst  sport  dport
# 0   192.168.0.252  192.168.0.14  39620  64188
# 1   192.168.0.252  192.168.0.14  39620  64188
# 2   192.168.0.252  192.168.0.14  39620  64188
# 3   192.168.0.252  192.168.0.14  39620  64188
# 4   192.168.0.252  192.168.0.14  39620  64188
# ..            ...           ...    ...    ...
# 75    84.54.22.33    10.1.10.53     53     53
# 76     10.1.10.53   84.54.22.33     53     53
# 77    84.54.22.33    10.1.10.53     53     53
# 78     10.1.10.53   84.54.22.33     53     53
# 79    84.54.22.33    10.1.10.53     53     53
#
# [80 rows x 4 columns]

# %%
<h3 style="color:rgb(102, 166, 38);">Estadísticas</h3>
